# %%
import numpy as np
import tensorflow as tf

# 1. Small toy dataset (keep it simple)
text = "hello world hello world hello world"

# 2. Create vocabulary
chars = sorted(set(text))
char_to_idx = {c: i for i, c in enumerate(chars)}
idx_to_char = {i: c for i, c in enumerate(chars)}

# 3. Create sequences
seq_length = 5
X = []
y = []

for i in range(len(text) - seq_length):
    seq = text[i:i+seq_length]
    target = text[i+seq_length]

    X.append([char_to_idx[c] for c in seq])
    y.append(char_to_idx[target])

X = np.array(X)
y = np.array(y)

# 4. Reshape for LSTM
X = X.reshape((X.shape[0], X.shape[1], 1)) / len(chars)

# 5. Build simple LSTM model
model = tf.keras.Sequential([
    tf.keras.layers.LSTM(32, input_shape=(seq_length, 1)),
    tf.keras.layers.Dense(len(chars), activation='softmax')
])

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')

# 6. Train
model.fit(X, y, epochs=50, verbose=1)

# 7. Generate text
def generate(seed="hello", length=20):
    result = seed

    for _ in range(length):
        x_input = np.array([[char_to_idx[c] for c in result[-seq_length:]]])
        x_input = x_input.reshape((1, seq_length, 1)) / len(chars)

        pred = model.predict(x_input, verbose=0)
        next_char = idx_to_char[np.argmax(pred)]

        result += next_char

    return result

# 8. Test
print(generate("hello", 30))
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 2.0901
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 2.0874
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 2.0848
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 2.0822
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 2.0796
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 2.0772
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 2.0747
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 2.0723
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 2.0699
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 2.0676
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 2.0653
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 2.0631
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 2.0609
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 2.0587
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 2.0565
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 2.0544
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 2.0522
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 2.0501
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 2.0481
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 2.0460
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 2.0439
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 2.0419
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 2.0399
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 2.0379
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 2.0359
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 2.0339
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 2.0319
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 2.0299
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 2.0279
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 2.0260
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 2.0240
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 2.0221
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 2.0202
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 2.0183
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 2.0164
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 2.0145
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 2.0127
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 2.0108
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2.0091
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 2.0073
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 2.0056
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 2.0039
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 2.0022
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 2.0006
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.9990
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 1.9975
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 1.9960
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 1.9946
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.9932
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.9918
# hello l lll l lll l lll l lll l lll
